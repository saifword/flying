# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
df_us = pd.read_csv('./data/us_passengers.csv')

# %%
df_airport = pd.read_excel('./data/global_airports.xls')

# %%
df_us
# Out:
#          Sum_PASSENGERS  AIRLINE_ID CARRIER_NAME ORIGIN  \
# 0                     0         NaN          NaN    AEX
# 1                     0         NaN          NaN    AEX
# 2                     0         NaN          NaN    AEX
# 3                    89         NaN          NaN    AEX
# 4                   108         NaN          NaN    AEX
# ...                 ...         ...          ...    ...
# 6278815               5     22074.0  Avon Jet AG    MFE
# 6278816               2     22074.0  Avon Jet AG    PBI
# 6278817               6     22074.0  Avon Jet AG    TEB
# 6278818               3     22074.0  Avon Jet AG    TEB
# 6278819               2     22074.0  Avon Jet AG    TEB
#
#                        ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  \
# 0                        Alexandria, LA               LA       Louisiana
# 1                        Alexandria, LA               LA       Louisiana
# ...

# %%
df_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6278820 entries, 0 to 6278819
# Data columns (total 17 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Sum_PASSENGERS       int64
#  1   AIRLINE_ID           float64
#  2   CARRIER_NAME         object
#  3   ORIGIN               object
#  4   ORIGIN_CITY_NAME     object
#  5   ORIGIN_STATE_ABR     object
#  6   ORIGIN_STATE_NM      object
#  7   ORIGIN_COUNTRY       object
#  8   ORIGIN_COUNTRY_NAME  object
#  9   DEST                 object
#  10  DEST_CITY_NAME       object
#  11  DEST_STATE_ABR       object
#  12  DEST_STATE_NM        object
#  13  DEST_COUNTRY         object
#  14  DEST_COUNTRY_NAME    object
#  15  YEAR                 int64
#  16  MONTH                int64
# dtypes: float64(1), int64(3), object(13)
# memory usage: 814.4+ MB

# %%
domestic = df_us[df_us['DEST_COUNTRY'] == 'US']

# %%
domestic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5571449 entries, 0 to 6278814
# Data columns (total 17 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Sum_PASSENGERS       int64
#  1   AIRLINE_ID           float64
#  2   CARRIER_NAME         object
#  3   ORIGIN               object
#  4   ORIGIN_CITY_NAME     object
#  5   ORIGIN_STATE_ABR     object
#  6   ORIGIN_STATE_NM      object
#  7   ORIGIN_COUNTRY       object
#  8   ORIGIN_COUNTRY_NAME  object
#  9   DEST                 object
#  10  DEST_CITY_NAME       object
#  11  DEST_STATE_ABR       object
#  12  DEST_STATE_NM        object
#  13  DEST_COUNTRY         object
#  14  DEST_COUNTRY_NAME    object
#  15  YEAR                 int64
#  16  MONTH                int64
# dtypes: float64(1), int64(3), object(13)
# memory usage: 765.1+ MB

# %%
df_us['CARRIER_NAME'].value_counts().head(10)
# Out:
# Southwest Airlines Co.         607779
# United Air Lines Inc.          355274
# Delta Air Lines Inc.           328820
# American Airlines Inc.         300494
# Federal Express Corporation    230797
# ExpressJet Airlines Inc.       202573
# SkyWest Airlines Inc.          201424
# US Airways Inc.                189380
# Northwest Airlines Inc.        138538
# United Parcel Service          133121
# Name: CARRIER_NAME, dtype: int64

# %%
domestic['CARRIER_NAME'].value_counts().head(10)
# Out:
# Southwest Airlines Co.         604964
# United Air Lines Inc.          300181
# Delta Air Lines Inc.           280427
# American Airlines Inc.         247872
# Federal Express Corporation    211708
# SkyWest Airlines Inc.          195702
# ExpressJet Airlines Inc.       189406
# US Airways Inc.                166053
# Northwest Airlines Inc.        125312
# United Parcel Service          122407
# Name: CARRIER_NAME, dtype: int64

# %%
datetime = pd.to_datetime(df_us.YEAR+df_us.MONTH,format='%Y%m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-df817f4aade6> in <module>
# ----> 1 datetime = pd.to_datetime(df_us.YEAR+df_us.MONTH,format='%Y%m')
#
# ...

# %% [markdown]
# This is why it's good to just try things out.  You'll stumble upon data issues that might need taking care of.

# %%
df_us[df_us['YEAR'] == 2000 & df_us['MONTH'] == 5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-09c8f421c3f7> in <module>
# ----> 1 df_us[df_us['YEAR'] == 2000 & df_us['MONTH'] == 5]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
